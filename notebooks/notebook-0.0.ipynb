# %% [markdown]
# # Transformacion de datos para el modelo

# %% [markdown]
# ## Importando librerias necesarias

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import OrdinalEncoder
import seaborn as sns
from imblearn.under_sampling import RandomUnderSampler

# %% [markdown]
# ## Informacion del dataset

# %% [markdown]
# - **trans_date_trans_time**: Fecha y hora de la transacción.
# - **cc_num**: Número de la tarjeta de crédito utilizada.
# - **merchant**: Nombre del comerciante donde se realizó la transacción.
# - **category**: Categoría del comercio (por ejemplo, restaurante, supermercado, etc.).
# - **amt**: Monto de la transacción.
# - **first**: Primer nombre del titular de la tarjeta.
# - **last**: Apellido del titular de la tarjeta.
# - **gender**: Género del titular de la tarjeta.
# - **street**: Dirección de residencia del titular de la tarjeta.
# - **city**: Ciudad de residencia del titular de la tarjeta.
# - **state**: Estado de residencia del titular de la tarjeta.
# - **zip**: Código postal de la residencia del titular de la tarjeta.
# - **lat**: Latitud de la residencia del titular de la tarjeta.
# - **long**: Longitud de la residencia del titular de la tarjeta.
# - **city_pop**: Población de la ciudad donde reside el titular de la tarjeta.
# - **job**: Ocupación del titular de la tarjeta.
# - **dob**: Fecha de nacimiento del titular de la tarjeta.
# - **trans_num**: Número de identificación de la transacción.
# - **unix_time**: Marca de tiempo en formato Unix para la transacción.
# - **merch_lat**: Latitud del comerciante donde se realizó la transacción.
# - **merch_long**: Longitud del comerciante donde se realizó la transacción.
# - **is_fraud**: Indicador de si la transacción es fraudulenta (1) o no (0).

# %% [markdown]
# ## Cargando Datos

# %%
data_train = pd.read_csv("../data/fraudTrain.csv")

# %%
data_train.head(3)
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2019-01-01 00:00:18  2703186189652095
# 1           1   2019-01-01 00:00:44      630423337322
# 2           2   2019-01-01 00:00:51    38859492057661
#
#                           merchant       category     amt      first     last  \
# 0       fraud_Rippin, Kub and Mann       misc_net    4.97   Jennifer    Banks
# 1  fraud_Heller, Gutmann and Zieme    grocery_pos  107.23  Stephanie     Gill
# 2             fraud_Lind-Buckridge  entertainment  220.11     Edward  Sanchez
#
#   gender                        street  ...      lat      long  city_pop  \
# 0      F                561 Perry Cove  ...  36.0788  -81.1781      3495
# 1      F  43039 Riley Greens Suite 393  ...  48.8878 -118.2105       149
# 2      M      594 White Dale Suite 530  ...  42.1808 -112.2620      4154
#
#                                  job         dob  \
# 0          Psychologist, counselling  1988-03-09
# 1  Special educational needs teacher  1978-06-21
# 2        Nature conservation officer  1962-01-19
#
#                           trans_num   unix_time  merch_lat  merch_long  \
# 0  0b242abb623afc578575680df30655b9  1325376018  36.011293  -82.048315
# 1  1f76529f8574734946361c461b024d99  1325376044  49.159047 -118.186462
# 2  a1a22d70485983eac12b5b88dad1cf95  1325376051  43.150704 -112.154481
#
#    is_fraud
# 0         0
# 1         0
# 2         0
#
# [3 rows x 23 columns]

# %%
data_train.shape
# Out:
# (1296675, 23)

# %% [markdown]
# ## Analisis de datos

# %% [markdown]
# ### Informacion de tipos de datos

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1296675 entries, 0 to 1296674
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   Unnamed: 0             1296675 non-null  int64
#  1   trans_date_trans_time  1296675 non-null  object
#  2   cc_num                 1296675 non-null  int64
#  3   merchant               1296675 non-null  object
#  4   category               1296675 non-null  object
#  5   amt                    1296675 non-null  float64
#  6   first                  1296675 non-null  object
#  7   last                   1296675 non-null  object
#  8   gender                 1296675 non-null  object
#  9   street                 1296675 non-null  object
#  10  city                   1296675 non-null  object
#  11  state                  1296675 non-null  object
#  12  zip                    1296675 non-null  int64
#  13  lat                    1296675 non-null  float64
#  14  long                   1296675 non-null  float64
#  15  city_pop               1296675 non-null  int64
#  16  job                    1296675 non-null  object
#  17  dob                    1296675 non-null  object
#  18  trans_num              1296675 non-null  object
#  19  unix_time              1296675 non-null  int64
#  20  merch_lat              1296675 non-null  float64
#  21  merch_long             1296675 non-null  float64
#  22  is_fraud               1296675 non-null  int64
# dtypes: float64(5), int64(6), object(12)
# memory usage: 227.5+ MB

# %% [markdown]
# ### Numero de clases

# %%
data_train.is_fraud.value_counts()
# Out:
# is_fraud
# 0    1289169
# 1       7506
# Name: count, dtype: int64

# %% [markdown]
# ### Valores nulos

# %%
data_train.isnull().sum()
# Out:
# Unnamed: 0               0
# trans_date_trans_time    0
# cc_num                   0
# merchant                 0
# category                 0
# amt                      0
# first                    0
# last                     0
# gender                   0
# street                   0
# city                     0
# state                    0
# zip                      0
# lat                      0
# long                     0
# city_pop                 0
# job                      0
# dob                      0
# trans_num                0
# unix_time                0
# merch_lat                0
# merch_long               0
# is_fraud                 0
# dtype: int64

# %% [markdown]
# ### Numero de duplicados

# %%
data_train.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Limpieza de datos

# %% [markdown]
# ### Equilibracion de clases

# %%
rus = RandomUnderSampler(random_state=42)
X = data_train.drop("is_fraud",axis=1) # <-- es tu conjunto de características.
Y = data_train.is_fraud # <--- es tu conjunto de etiquetas o clases.

X_over, y_over = rus.fit_resample(X,Y)
y_over.unique()

data = pd.concat([X_over, y_over] , axis = 1)

# %%
data.shape
# Out:
# (15012, 23)

# %% [markdown]
# ### Granulacion de la columna trans_date_trans_time

# %%
data['trans_date_trans_time'] = pd.to_datetime(data['trans_date_trans_time'], format='%Y-%m-%d %H:%M:%S')
data.head(3)
# Out:
#          Unnamed: 0 trans_date_trans_time            cc_num  \
# 811778       811778   2019-12-07 10:55:06      676173792455
# 1101718     1101718   2020-04-03 13:10:06    30518206766474
# 800013       800013   2019-12-04 07:07:04  4658490815480264
#
#                              merchant       category    amt     first  \
# 811778   fraud_Zieme, Bode and Dooley  gas_transport  86.19  Brittany
# 1101718          fraud_Lind-Buckridge  entertainment  85.81    Tamara
# 800013        fraud_Hackett-Lueilwitz    grocery_pos  99.30      Tara
#
#              last gender                         street  ...      lat  \
# 811778        Cox      F    07177 William Dale Apt. 547  ...  34.0287
# 1101718  Martinez      F  471 Marquez Prairie Suite 680  ...  36.7154
# 800013   Richards      F          4879 Cristina Station  ...  39.9636
#
#              long  city_pop                          job         dob  \
# 811778  -118.4924     92043  Civil engineer, contracting  1961-04-25
# 1101718  -89.6287      1019        Aeronautical engineer  1979-01-26
# 800013   -79.7853       184            Systems developer  1945-11-04
#
#                                 trans_num   unix_time  merch_lat  merch_long  \
# 811778   f32d1f4b2a918f4c2f6acdc83033ee35  1354877706  33.287851 -118.740970
# 1101718  f5dad8e2d7c39d81502d846a20286659  1364994606  36.539950  -89.857416
# 800013   1d023bc78ab93ab65a35bbb53bcc67bd  1354604824  39.582872  -78.838550
#
#          is_fraud
# 811778          0
# 1101718         0
# 800013          0
#
# [3 rows x 23 columns]

# %%
data['date'] = data['trans_date_trans_time'].dt.date
data['time'] = data['trans_date_trans_time'].dt.time
data.head(3)
# Out:
#          Unnamed: 0 trans_date_trans_time            cc_num  \
# 811778       811778   2019-12-07 10:55:06      676173792455
# 1101718     1101718   2020-04-03 13:10:06    30518206766474
# 800013       800013   2019-12-04 07:07:04  4658490815480264
#
#                              merchant       category    amt     first  \
# 811778   fraud_Zieme, Bode and Dooley  gas_transport  86.19  Brittany
# 1101718          fraud_Lind-Buckridge  entertainment  85.81    Tamara
# 800013        fraud_Hackett-Lueilwitz    grocery_pos  99.30      Tara
#
#              last gender                         street  ... city_pop  \
# 811778        Cox      F    07177 William Dale Apt. 547  ...    92043
# 1101718  Martinez      F  471 Marquez Prairie Suite 680  ...     1019
# 800013   Richards      F          4879 Cristina Station  ...      184
#
#                                  job         dob  \
# 811778   Civil engineer, contracting  1961-04-25
# 1101718        Aeronautical engineer  1979-01-26
# 800013             Systems developer  1945-11-04
#
#                                 trans_num   unix_time  merch_lat  merch_long  \
# 811778   f32d1f4b2a918f4c2f6acdc83033ee35  1354877706  33.287851 -118.740970
# 1101718  f5dad8e2d7c39d81502d846a20286659  1364994606  36.539950  -89.857416
# 800013   1d023bc78ab93ab65a35bbb53bcc67bd  1354604824  39.582872  -78.838550
#
#         is_fraud        date      time
# 811778         0  2019-12-07  10:55:06
# 1101718        0  2020-04-03  13:10:06
# 800013         0  2019-12-04  07:07:04
#
# [3 rows x 25 columns]

# %% [markdown]
# ### Organizando columnas

# %%
columnas = ['date','time'] + [ col for col in data.columns if col not in ['date','time']]
data = data[columnas]
data.drop(columns=['trans_date_trans_time'], axis= 1 , inplace=True)

# %%
data.head(3)
# Out:
#                date      time  Unnamed: 0            cc_num  \
# 811778   2019-12-07  10:55:06      811778      676173792455
# 1101718  2020-04-03  13:10:06     1101718    30518206766474
# 800013   2019-12-04  07:07:04      800013  4658490815480264
#
#                              merchant       category    amt     first  \
# 811778   fraud_Zieme, Bode and Dooley  gas_transport  86.19  Brittany
# 1101718          fraud_Lind-Buckridge  entertainment  85.81    Tamara
# 800013        fraud_Hackett-Lueilwitz    grocery_pos  99.30      Tara
#
#              last gender  ...      lat      long city_pop  \
# 811778        Cox      F  ...  34.0287 -118.4924    92043
# 1101718  Martinez      F  ...  36.7154  -89.6287     1019
# 800013   Richards      F  ...  39.9636  -79.7853      184
#
#                                  job         dob  \
# 811778   Civil engineer, contracting  1961-04-25
# 1101718        Aeronautical engineer  1979-01-26
# 800013             Systems developer  1945-11-04
#
#                                 trans_num   unix_time  merch_lat  merch_long  \
# 811778   f32d1f4b2a918f4c2f6acdc83033ee35  1354877706  33.287851 -118.740970
# 1101718  f5dad8e2d7c39d81502d846a20286659  1364994606  36.539950  -89.857416
# 800013   1d023bc78ab93ab65a35bbb53bcc67bd  1354604824  39.582872  -78.838550
#
#         is_fraud
# 811778         0
# 1101718        0
# 800013         0
#
# [3 rows x 24 columns]

# %% [markdown]
# ### Tranformando columna de numero de tarjeta a numero de veces usada

# %%
card_transaction_counts = data['cc_num'].value_counts()
data['card_transaction_count'] = data['cc_num'].map(card_transaction_counts)
data.drop(columns=['cc_num'] , axis = 1 , inplace=True)

# %%
data.head(3)
# Out:
#                date      time  Unnamed: 0                      merchant  \
# 811778   2019-12-07  10:55:06      811778  fraud_Zieme, Bode and Dooley
# 1101718  2020-04-03  13:10:06     1101718          fraud_Lind-Buckridge
# 800013   2019-12-04  07:07:04      800013       fraud_Hackett-Lueilwitz
#
#               category    amt     first      last gender  \
# 811778   gas_transport  86.19  Brittany       Cox      F
# 1101718  entertainment  85.81    Tamara  Martinez      F
# 800013     grocery_pos  99.30      Tara  Richards      F
#
#                                 street  ...      long city_pop  \
# 811778     07177 William Dale Apt. 547  ... -118.4924    92043
# 1101718  471 Marquez Prairie Suite 680  ...  -89.6287     1019
# 800013           4879 Cristina Station  ...  -79.7853      184
#
#                                  job         dob  \
# 811778   Civil engineer, contracting  1961-04-25
# 1101718        Aeronautical engineer  1979-01-26
# 800013             Systems developer  1945-11-04
#
#                                 trans_num   unix_time  merch_lat  merch_long  \
# 811778   f32d1f4b2a918f4c2f6acdc83033ee35  1354877706  33.287851 -118.740970
# 1101718  f5dad8e2d7c39d81502d846a20286659  1364994606  36.539950  -89.857416
# 800013   1d023bc78ab93ab65a35bbb53bcc67bd  1354604824  39.582872  -78.838550
#
#         is_fraud  card_transaction_count
# 811778         0                      14
# 1101718        0                      24
# 800013         0                       9
#
# [3 rows x 24 columns]

# %% [markdown]
# ### Analizando colmunas numericas

# %%
data_numeric = data.select_dtypes(include=np.number)

# %%
data_numeric
# Out:
#          Unnamed: 0      amt    zip      lat      long  city_pop   unix_time  \
# 811778       811778    86.19  90403  34.0287 -118.4924     92043  1354877706
# 1101718     1101718    85.81  63867  36.7154  -89.6287      1019  1364994606
# 800013       800013    99.30  15449  39.9636  -79.7853       184  1354604824
# 398945       398945    42.09  59448  48.2777 -112.8456       743  1341081788
# 207455       207455     4.24  37663  36.4715  -82.4834     87124  1334519869
# ...             ...      ...    ...      ...       ...       ...         ...
# 1295399     1295399   977.01  32960  27.6330  -80.4031    105638  1371776408
# 1295491     1295491  1210.91  32960  27.6330  -80.4031    105638  1371779615
# 1295532     1295532    10.24  70726  30.4590  -90.9027     71335  1371781016
# 1295666     1295666    21.69  79759  31.8599 -102.7413        23  1371785180
# 1295733     1295733    10.20  70726  30.4590  -90.9027     71335  1371787186
#
#          merch_lat  merch_long  is_fraud  card_transaction_count
# 811778   33.287851 -118.740970         0                      14
# 1101718  36.539950  -89.857416         0                      24
# 800013   39.582872  -78.838550         0                       9
# 398945   48.310513 -112.837535         0                      26
# 207455   37.329094  -82.070746         0                      10
# ...            ...         ...       ...                     ...
# 1295399  26.888686  -80.834389         1                      12
# 1295491  28.216707  -79.855648         1                      12
# 1295532  29.700456  -91.361632         1                      23
# 1295666  32.675272 -103.484949         1                      12
# 1295733  31.363252  -89.932309         1                      23
#
# [15012 rows x 11 columns]

# %%
data_numeric.corr()['is_fraud'].sort_values(ascending=True)
# Out:
# card_transaction_count   -0.051759
# unix_time                -0.032213
# Unnamed: 0               -0.029827
# zip                      -0.025534
# merch_lat                 0.008015
# lat                       0.008472
# city_pop                  0.022290
# merch_long                0.025498
# long                      0.025504
# amt                       0.619952
# is_fraud                  1.000000
# Name: is_fraud, dtype: float64

# %%
data_numeric.corr()['is_fraud'].sort_values(ascending=True).plot(kind='bar')
plt.grid()

# %% [markdown]
# ### Eliminacion de columnas innecesarias

# %%
data.drop(columns=["Unnamed: 0", 'first','last','street','trans_num','city','state','merchant','job', 'unix_time'], inplace=True)

# %% [markdown]
# ### Ordenando columnas

# %%
columnas = ['card_transaction_count'] + [ col for col in data.columns if col not in ['card_transaction_count']]
data = data[columnas]
data.head(3)
# Out:
#          card_transaction_count        date      time       category    amt  \
# 811778                       14  2019-12-07  10:55:06  gas_transport  86.19
# 1101718                      24  2020-04-03  13:10:06  entertainment  85.81
# 800013                        9  2019-12-04  07:07:04    grocery_pos  99.30
#
#         gender    zip      lat      long  city_pop         dob  merch_lat  \
# 811778       F  90403  34.0287 -118.4924     92043  1961-04-25  33.287851
# 1101718      F  63867  36.7154  -89.6287      1019  1979-01-26  36.539950
# 800013       F  15449  39.9636  -79.7853       184  1945-11-04  39.582872
#
#          merch_long  is_fraud
# 811778  -118.740970         0
# 1101718  -89.857416         0
# 800013   -78.838550         0

# %% [markdown]
# ### Granulacion de columnas date y time

# %%
data['date'] = pd.to_datetime(data['date'] , format='%Y-%m-%d')
data['time'] = pd.to_datetime(data['time'] , format ='%H:%M:%S')

data['year'] = data['date'].dt.year
data['week'] = data['date'].dt.weekday
data['month'] = data['date'].dt.month
data['hour'] = data['time'].dt.hour

# %%
data.drop(columns=['date' , 'time'] , inplace=True)

# %%
data.head()
# Out:
#          card_transaction_count       category    amt gender    zip      lat  \
# 811778                       14  gas_transport  86.19      F  90403  34.0287
# 1101718                      24  entertainment  85.81      F  63867  36.7154
# 800013                        9    grocery_pos  99.30      F  15449  39.9636
# 398945                       26           home  42.09      F  59448  48.2777
# 207455                       10   shopping_net   4.24      F  37663  36.4715
#
#              long  city_pop         dob  merch_lat  merch_long  is_fraud  \
# 811778  -118.4924     92043  1961-04-25  33.287851 -118.740970         0
# 1101718  -89.6287      1019  1979-01-26  36.539950  -89.857416         0
# 800013   -79.7853       184  1945-11-04  39.582872  -78.838550         0
# 398945  -112.8456       743  1972-05-04  48.310513 -112.837535         0
# 207455   -82.4834     87124  1987-02-14  37.329094  -82.070746         0
#
#          year  week  month  hour
# 811778   2019     5     12    10
# 1101718  2020     4      4    13
# 800013   2019     2     12     7
# 398945   2019     6      6    18
# 207455   2019     0      4    19

# %% [markdown]
# ### Transformaciones ciclicas para datos temporales

# %%
data["hour_sin"] = np.sin( 2 * np.pi * (data["hour"] / 24))
data["hour_cos"] = np.cos( 2 * np.pi * (data["hour"] / 24))

data["week_sin"] = np.sin( 2 * np.pi * (data["week"] / 7))
data["week_cos"] = np.cos( 2 * np.pi * (data["week"] / 7))

data['month_sin'] = np.sin(2 * np.pi * (data['month'] / 12.0))
data['month_cos'] = np.cos(2 * np.pi * (data['month'] / 12.0))

# %%
data.head()
# Out:
#          card_transaction_count       category    amt gender    zip      lat  \
# 811778                       14  gas_transport  86.19      F  90403  34.0287
# 1101718                      24  entertainment  85.81      F  63867  36.7154
# 800013                        9    grocery_pos  99.30      F  15449  39.9636
# 398945                       26           home  42.09      F  59448  48.2777
# 207455                       10   shopping_net   4.24      F  37663  36.4715
#
#              long  city_pop         dob  merch_lat  ...  year  week  month  \
# 811778  -118.4924     92043  1961-04-25  33.287851  ...  2019     5     12
# 1101718  -89.6287      1019  1979-01-26  36.539950  ...  2020     4      4
# 800013   -79.7853       184  1945-11-04  39.582872  ...  2019     2     12
# 398945  -112.8456       743  1972-05-04  48.310513  ...  2019     6      6
# 207455   -82.4834     87124  1987-02-14  37.329094  ...  2019     0      4
#
#          hour  hour_sin      hour_cos  week_sin  week_cos     month_sin  \
# 811778     10  0.500000 -8.660254e-01 -0.974928 -0.222521 -2.449294e-16
# 1101718    13 -0.258819 -9.659258e-01 -0.433884 -0.900969  8.660254e-01
# 800013      7  0.965926 -2.588190e-01  0.974928 -0.222521 -2.449294e-16
# 398945     18 -1.000000 -1.836970e-16 -0.781831  0.623490  1.224647e-16
# 207455     19 -0.965926  2.588190e-01  0.000000  1.000000  8.660254e-01
#
#          month_cos
# 811778         1.0
# 1101718       -0.5
# 800013         1.0
# 398945        -1.0
# 207455        -0.5
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Transformando columna fecha_nacimiento(dob) a edad actual del titular(age)

# %%
data['dob'] = pd.to_datetime(data['dob'] , format='%Y-%m-%d')
data['year2'] = data['dob'].dt.year
data['age'] = data[['year2' , 'year']].apply(
    lambda x : x['year'] - x['year2'] , axis = 1
)

# %%
data.drop(columns=['year2' ,'dob' , 'year' , 'month' , 'hour'] , inplace=True)
data.drop(columns=['week'] , axis = 1 , inplace = True)

# %%
columnas = ['hour_sin' , 'hour_cos' , 'week_sin', 'week_cos' , 'month_sin', 'month_cos' , 'age'] + [ col for col in data.columns if col not in ['hour_sin' , 'hour_cos' , 'week_sin', 'week_cos' , 'month_sin', 'month_cos' , 'age' ]]
data = data[columnas]

# %%
data.head()
# Out:
#          hour_sin      hour_cos  week_sin  week_cos     month_sin  month_cos  \
# 811778   0.500000 -8.660254e-01 -0.974928 -0.222521 -2.449294e-16        1.0
# 1101718 -0.258819 -9.659258e-01 -0.433884 -0.900969  8.660254e-01       -0.5
# 800013   0.965926 -2.588190e-01  0.974928 -0.222521 -2.449294e-16        1.0
# 398945  -1.000000 -1.836970e-16 -0.781831  0.623490  1.224647e-16       -1.0
# 207455  -0.965926  2.588190e-01  0.000000  1.000000  8.660254e-01       -0.5
#
#          age  card_transaction_count       category    amt gender    zip  \
# 811778    58                      14  gas_transport  86.19      F  90403
# 1101718   41                      24  entertainment  85.81      F  63867
# 800013    74                       9    grocery_pos  99.30      F  15449
# 398945    47                      26           home  42.09      F  59448
# 207455    32                      10   shopping_net   4.24      F  37663
#
#              lat      long  city_pop  merch_lat  merch_long  is_fraud
# 811778   34.0287 -118.4924     92043  33.287851 -118.740970         0
# 1101718  36.7154  -89.6287      1019  36.539950  -89.857416         0
# 800013   39.9636  -79.7853       184  39.582872  -78.838550         0
# 398945   48.2777 -112.8456       743  48.310513 -112.837535         0
# 207455   36.4715  -82.4834     87124  37.329094  -82.070746         0

# %% [markdown]
# ### Codificando a numero columnas categoricas

# %%
encoder = OrdinalEncoder()
data_categoric = data.select_dtypes(exclude = np.number)
data_become_numeric = encoder.fit_transform(data_categoric)
data[['category' , 'gender']] = data_become_numeric

# %% [markdown]
# ### Analizando correlaciond e variables resultantes

# %%
print(data.corr()['is_fraud'].sort_values(ascending=True))
data.corr()['is_fraud'].sort_values(ascending=True).plot(kind='bar')
plt.grid()
# Out:
# week_cos                 -0.068501
# card_transaction_count   -0.051759
# zip                      -0.025534
# merch_lat                 0.008015
# lat                       0.008472
# hour_sin                  0.012407
# week_sin                  0.020795
# city_pop                  0.022290
# merch_long                0.025498
# long                      0.025504
# gender                    0.048675
# month_cos                 0.055109
# month_sin                 0.058410
# age                       0.069362
# category                  0.128425
# hour_cos                  0.535631
# amt                       0.619952
# is_fraud                  1.000000
# Name: is_fraud, dtype: float64

# %% [markdown]
# ### Exportando los datos transformado para el modelo

# %%
data.to_csv('../data/data_tranform.csv' , index= False)
